# %% [markdown]
# ## Advanced Big Data Analytics - Assignment 2

# %% [markdown]
# ### Load packages

# %%
import pandas as pd

# %% [markdown]
# ### Load data

# %%
metadata = pd.read_json("metadata.json")

# %%
metadata.head()
# Out:
#                                          42.7363609_2.8868181.png  \
# has_pool                                                     True
# center                      {'lat': 42.7363609, 'lon': 2.8868181}
# bounds_lat_lon  [{'lat': 42.7364046, 'lon': 2.8867693}, {'lat'...
# bounds_x_y      [{'x': 219.88854424638464, 'y': 197.9724640370...
#
#                                           42.7008031_2.906998.png  \
# has_pool                                                     True
# center             {'lat': 42.7008031, 'lon': 2.9069979999999997}
# bounds_lat_lon  [{'lat': 42.700821, 'lon': 2.9069484}, {'lat':...
# bounds_x_y      [{'x': 219.31757991040274, 'y': 223.9864984406...
#
#                                          42.6892307_2.9110119.png  \
# has_pool                                                     True
# center                      {'lat': 42.6892307, 'lon': 2.9110119}
# bounds_lat_lon  [{'lat': 42.6891823, 'lon': 2.9110157}, {'lat'...
# ...

# %%
metadata.iloc[-1,0]
# Out:
# [{'x': 219.88854424638464, 'y': 197.97246403701524},
#  {'x': 199.24285541121722, 'y': 243.81349049302645},
#  {'x': 292.03745689232903, 'y': 286.02750490829436},
#  {'x': 312.75714461835867, 'y': 240.08575994312486},
#  {'x': 219.88854424638464, 'y': 197.97246403701524}]
